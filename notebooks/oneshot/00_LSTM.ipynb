# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')
tfk = tf.keras
tfkl = tf.keras.layers

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset = pd.read_csv('../input/hw2dataset/Training.csv')
print(dataset.shape) 
dataset.head().transpose()
# Out:
# (68528, 7)
#                            0          1         2          3          4
# Sponginess           7.97698   8.078240   8.02844   8.028440   7.875720
# Wonder level         4.33494   4.446160   4.22372   4.223720   4.446160
# Crunchiness         10.67282  10.561600  10.56160  10.561600  10.450380
# Loudness on impact   1.76692   1.707160   1.64906   1.707160   1.707160
# Meme creativity      3.22440   3.325660   3.17460   3.174600   3.275860
# Soap slipperiness   51.68146  51.563598  50.86308  45.841581  47.126421
# Hype root            3.65434   3.476720   3.47672   3.476720   3.476720

# %%
dataset.head()
# Out:
#    Sponginess  Wonder level  Crunchiness  Loudness on impact  Meme creativity  \
# 0     7.97698       4.33494     10.67282             1.76692          3.22440
# 1     8.07824       4.44616     10.56160             1.70716          3.32566
# 2     8.02844       4.22372     10.56160             1.64906          3.17460
# 3     8.02844       4.22372     10.56160             1.70716          3.17460
# 4     7.87572       4.44616     10.45038             1.70716          3.27586
#
#    Soap slipperiness  Hype root
# 0          51.681460    3.65434
# 1          51.563598    3.47672
# 2          50.863080    3.47672
# 3          45.841581    3.47672
# 4          47.126421    3.47672

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68528 entries, 0 to 68527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68528 non-null  float64
#  1   Wonder level        68528 non-null  float64
#  2   Crunchiness         68528 non-null  float64
#  3   Loudness on impact  68528 non-null  float64
#  4   Meme creativity     68528 non-null  float64
#  5   Soap slipperiness   68528 non-null  float64
#  6   Hype root           68528 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
inspect_dataframe(dataset, dataset.columns)

# %%
test_size = 10000
X_train_raw = dataset.iloc[:-test_size]
# y_train_raw = y.iloc[:-test_size]
X_test_raw = dataset.iloc[-test_size:]
# y_test_raw = y.iloc[-test_size:]
print(X_train_raw.shape, X_test_raw.shape)

# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)
# Out:
# (58528, 7) (10000, 7)

# %%
def build_sequences(df, target_labels, window, stride, telescope):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')#float32
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
target_labels = dataset.columns
window = 200
stride = 10
telescope = 100

# %%
future = dataset[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 200, 7)

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((5830, 200, 7), (5830, 100, 7), (970, 200, 7), (970, 100, 7))

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 128
epochs = 200

# %%
def build_model(input_shape ,output_shape):
    #create model
    model = tfk.Sequential()
    model.add(tfkl.LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(tfkl.Dropout(0.2))

    model.add(tfkl.LSTM(units=50, return_sequences=True))
    model.add(tfkl.Dropout(0.2))

    model.add(tfkl.LSTM(units=50))
    model.add(tfkl.Dropout(0.2))

    model.add(tfkl.Dense(output_shape[-1]*output_shape[-2], activation='relu'))
    model.add(tfkl.Reshape((output_shape[-2],output_shape[-1])))
    model.add(tfkl.Conv1D(output_shape[-1], 1, padding='same'))

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])


    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# 2021-12-14 18:35:48.926828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:49.022906: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:49.023767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:49.025033: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-14 18:35:49.025744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:49.026489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:49.027132: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:50.840562: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:50.841375: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:50.842043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 18:35:50.842635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200, 50)           11600
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 50)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 200, 50)           20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200, 50)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 700)               35700
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 7)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 100, 7)            56
# =================================================================
# Total params: 87,756
# Trainable params: 87,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.15,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# 2021-12-14 18:35:53.023857: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2021-12-14 18:35:57.183624: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 39/39 [==============================] - 12s 65ms/step - loss: 0.1481 - mae: 0.3197 - val_loss: 0.0324 - val_mae: 0.1422
# Epoch 2/200
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0377 - mae: 0.1523 - val_loss: 0.0230 - val_mae: 0.1202
# Epoch 3/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0285 - mae: 0.1312 - val_loss: 0.0227 - val_mae: 0.1199
# Epoch 4/200
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0247 - mae: 0.1214 - val_loss: 0.0222 - val_mae: 0.1136
# Epoch 5/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0227 - mae: 0.1159 - val_loss: 0.0242 - val_mae: 0.1267
# Epoch 6/200
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0206 - mae: 0.1110 - val_loss: 0.0238 - val_mae: 0.1278
# Epoch 7/200
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0194 - mae: 0.1070 - val_loss: 0.0225 - val_mae: 0.1225
# Epoch 8/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0185 - mae: 0.1037 - val_loss: 0.0216 - val_mae: 0.1205
# Epoch 9/200
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0180 - mae: 0.1017 - val_loss: 0.0217 - val_mae: 0.1184
# Epoch 10/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0175 - mae: 0.1001 - val_loss: 0.0213 - val_mae: 0.1177
# Epoch 11/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0174 - mae: 0.0995 - val_loss: 0.0193 - val_mae: 0.1103
# Epoch 12/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0170 - mae: 0.0983 - val_loss: 0.0186 - val_mae: 0.1075
# Epoch 13/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0165 - mae: 0.0967 - val_loss: 0.0179 - val_mae: 0.1053
# Epoch 14/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0163 - mae: 0.0959 - val_loss: 0.0172 - val_mae: 0.0994
# Epoch 15/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0161 - mae: 0.0951 - val_loss: 0.0166 - val_mae: 0.0977
# Epoch 16/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0158 - mae: 0.0942 - val_loss: 0.0169 - val_mae: 0.0994
# Epoch 17/200
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0156 - mae: 0.0931 - val_loss: 0.0166 - val_mae: 0.0975
# Epoch 18/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0155 - mae: 0.0931 - val_loss: 0.0167 - val_mae: 0.0985
# Epoch 19/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0152 - mae: 0.0920 - val_loss: 0.0170 - val_mae: 0.1010
# Epoch 20/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0150 - mae: 0.0916 - val_loss: 0.0167 - val_mae: 0.0990
# Epoch 21/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0148 - mae: 0.0911 - val_loss: 0.0159 - val_mae: 0.0943
# Epoch 22/200
# 39/39 [==============================] - 2s 39ms/step - loss: 0.0147 - mae: 0.0907 - val_loss: 0.0163 - val_mae: 0.0968
# Epoch 23/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0145 - mae: 0.0902 - val_loss: 0.0158 - val_mae: 0.0935
# Epoch 24/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0145 - mae: 0.0901 - val_loss: 0.0160 - val_mae: 0.0952
# Epoch 25/200
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0143 - mae: 0.0896 - val_loss: 0.0156 - val_mae: 0.0935
# Epoch 26/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0142 - mae: 0.0893 - val_loss: 0.0157 - val_mae: 0.0939
# Epoch 27/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0141 - mae: 0.0891 - val_loss: 0.0158 - val_mae: 0.0957
# Epoch 28/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0139 - mae: 0.0885 - val_loss: 0.0155 - val_mae: 0.0936
# Epoch 29/200
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0137 - mae: 0.0881 - val_loss: 0.0151 - val_mae: 0.0919
# Epoch 30/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0136 - mae: 0.0878 - val_loss: 0.0154 - val_mae: 0.0945
# Epoch 31/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0134 - mae: 0.0874 - val_loss: 0.0150 - val_mae: 0.0920
# Epoch 32/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0133 - mae: 0.0873 - val_loss: 0.0150 - val_mae: 0.0930
# Epoch 33/200
# 39/39 [==============================] - 2s 39ms/step - loss: 0.0131 - mae: 0.0866 - val_loss: 0.0148 - val_mae: 0.0925
# Epoch 34/200
# 39/39 [==============================] - 1s 36ms/step - loss: 0.0130 - mae: 0.0862 - val_loss: 0.0152 - val_mae: 0.0956
# Epoch 35/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0127 - mae: 0.0852 - val_loss: 0.0145 - val_mae: 0.0919
# Epoch 36/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0125 - mae: 0.0849 - val_loss: 0.0143 - val_mae: 0.0911
# Epoch 37/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0121 - mae: 0.0839 - val_loss: 0.0138 - val_mae: 0.0891
# Epoch 38/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0120 - mae: 0.0834 - val_loss: 0.0140 - val_mae: 0.0921
# Epoch 39/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0119 - mae: 0.0832 - val_loss: 0.0136 - val_mae: 0.0898
# Epoch 40/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0117 - mae: 0.0828 - val_loss: 0.0141 - val_mae: 0.0934
# Epoch 41/200
# 39/39 [==============================] - 1s 36ms/step - loss: 0.0117 - mae: 0.0826 - val_loss: 0.0138 - val_mae: 0.0909
# Epoch 42/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0116 - mae: 0.0822 - val_loss: 0.0136 - val_mae: 0.0896
# Epoch 43/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0114 - mae: 0.0818 - val_loss: 0.0136 - val_mae: 0.0898
# Epoch 44/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0114 - mae: 0.0817 - val_loss: 0.0137 - val_mae: 0.0892
# Epoch 45/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0111 - mae: 0.0808 - val_loss: 0.0135 - val_mae: 0.0897
# Epoch 46/200
# 39/39 [==============================] - 1s 38ms/step - loss: 0.0112 - mae: 0.0812 - val_loss: 0.0136 - val_mae: 0.0901
# Epoch 47/200
# 39/39 [==============================] - 1s 36ms/step - loss: 0.0111 - mae: 0.0808 - val_loss: 0.0135 - val_mae: 0.0896
# Epoch 48/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0111 - mae: 0.0809 - val_loss: 0.0134 - val_mae: 0.0888
# Epoch 49/200
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0110 - mae: 0.0805 - val_loss: 0.0133 - val_mae: 0.0889
# Epoch 50/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0110 - mae: 0.0803 - val_loss: 0.0132 - val_mae: 0.0881
# Epoch 51/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0109 - mae: 0.0800 - val_loss: 0.0134 - val_mae: 0.0897
# Epoch 52/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0109 - mae: 0.0800 - val_loss: 0.0131 - val_mae: 0.0876
# Epoch 53/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0108 - mae: 0.0797 - val_loss: 0.0133 - val_mae: 0.0887
# Epoch 54/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0108 - mae: 0.0798 - val_loss: 0.0132 - val_mae: 0.0885
# Epoch 55/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0108 - mae: 0.0794 - val_loss: 0.0130 - val_mae: 0.0878
# Epoch 56/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0107 - mae: 0.0793 - val_loss: 0.0131 - val_mae: 0.0883
# Epoch 57/200
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0107 - mae: 0.0794 - val_loss: 0.0133 - val_mae: 0.0896
# Epoch 58/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0107 - mae: 0.0793 - val_loss: 0.0131 - val_mae: 0.0886
# Epoch 59/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0106 - mae: 0.0789 - val_loss: 0.0129 - val_mae: 0.0876
# Epoch 60/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0106 - mae: 0.0789 - val_loss: 0.0128 - val_mae: 0.0870
# Epoch 61/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0106 - mae: 0.0788 - val_loss: 0.0131 - val_mae: 0.0887
# Epoch 62/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0105 - mae: 0.0783 - val_loss: 0.0130 - val_mae: 0.0888
# Epoch 63/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0104 - mae: 0.0782 - val_loss: 0.0128 - val_mae: 0.0875
# Epoch 64/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0104 - mae: 0.0780 - val_loss: 0.0128 - val_mae: 0.0878
# Epoch 65/200
# 39/39 [==============================] - 1s 36ms/step - loss: 0.0104 - mae: 0.0780 - val_loss: 0.0127 - val_mae: 0.0870
# Epoch 66/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0104 - mae: 0.0780 - val_loss: 0.0127 - val_mae: 0.0875
# Epoch 67/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0103 - mae: 0.0778 - val_loss: 0.0127 - val_mae: 0.0879
# Epoch 68/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0103 - mae: 0.0777 - val_loss: 0.0128 - val_mae: 0.0871
# Epoch 69/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0102 - mae: 0.0773 - val_loss: 0.0125 - val_mae: 0.0863
# Epoch 70/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0102 - mae: 0.0771 - val_loss: 0.0126 - val_mae: 0.0873
# Epoch 71/200
# 39/39 [==============================] - 2s 40ms/step - loss: 0.0102 - mae: 0.0772 - val_loss: 0.0125 - val_mae: 0.0864
# Epoch 72/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0101 - mae: 0.0770 - val_loss: 0.0124 - val_mae: 0.0865
# Epoch 73/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0102 - mae: 0.0771 - val_loss: 0.0124 - val_mae: 0.0862
# Epoch 74/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0101 - mae: 0.0769 - val_loss: 0.0123 - val_mae: 0.0859
# Epoch 75/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0100 - mae: 0.0767 - val_loss: 0.0123 - val_mae: 0.0859
# Epoch 76/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0101 - mae: 0.0767 - val_loss: 0.0125 - val_mae: 0.0868
# Epoch 77/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0101 - mae: 0.0767 - val_loss: 0.0125 - val_mae: 0.0871
# Epoch 78/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0100 - mae: 0.0766 - val_loss: 0.0124 - val_mae: 0.0861
# Epoch 79/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0100 - mae: 0.0764 - val_loss: 0.0123 - val_mae: 0.0862
# Epoch 80/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0100 - mae: 0.0765 - val_loss: 0.0124 - val_mae: 0.0860
# Epoch 81/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0100 - mae: 0.0765 - val_loss: 0.0124 - val_mae: 0.0861
# Epoch 82/200
# 39/39 [==============================] - 2s 41ms/step - loss: 0.0099 - mae: 0.0763 - val_loss: 0.0124 - val_mae: 0.0861
# Epoch 83/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0763 - val_loss: 0.0124 - val_mae: 0.0862
# Epoch 84/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0100 - mae: 0.0764 - val_loss: 0.0123 - val_mae: 0.0862
# Epoch 85/200
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0100 - mae: 0.0764 - val_loss: 0.0123 - val_mae: 0.0860
# Epoch 86/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0763 - val_loss: 0.0124 - val_mae: 0.0863
# Epoch 87/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0761 - val_loss: 0.0123 - val_mae: 0.0859
# Epoch 88/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0761 - val_loss: 0.0123 - val_mae: 0.0861
# Epoch 89/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0761 - val_loss: 0.0123 - val_mae: 0.0863
# Epoch 90/200
# 39/39 [==============================] - 1s 36ms/step - loss: 0.0099 - mae: 0.0762 - val_loss: 0.0123 - val_mae: 0.0864
# Epoch 91/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0762 - val_loss: 0.0123 - val_mae: 0.0861
# Epoch 92/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0762 - val_loss: 0.0123 - val_mae: 0.0860
# Epoch 93/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0759 - val_loss: 0.0123 - val_mae: 0.0861
# Epoch 94/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0760 - val_loss: 0.0123 - val_mae: 0.0861
# Epoch 95/200
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0099 - mae: 0.0761 - val_loss: 0.0123 - val_mae: 0.0862
# Epoch 96/200
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0099 - mae: 0.0760 - val_loss: 0.0123 - val_mae: 0.0863
# Epoch 97/200
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0099 - mae: 0.0762 - val_loss: 0.0123 - val_mae: 0.0859

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set 
predictions = model.predict(X_test)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (970, 100, 7)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.012071593>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.08041866>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, telescope)

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(y_test[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
future_predictions = model.predict(future)

# %%
figs, axs = plt.subplots(len(target_labels), 1, sharex=True, figsize=(17,17))
for i, col in enumerate(target_labels):
    axs[i].plot(np.arange(len(future[0,:,i])), future[0,:,i])
    axs[i].plot(np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), future_predictions[0,:,i], color='orange')
    axs[i].fill_between(
        np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), 
        future_predictions[0,:,i]+maes[:,i], 
        future_predictions[0,:,i]-maes[:,i], 
        color='orange', alpha=.3)
    axs[i].set_title(col)
    # axs[i].set_ylim(0,1)
plt.show()

# %%
model_name = 'LSTM'
exp_dir = ''
model.save(os.path.join(exp_dir, model_name))
# Out:
# 2021-12-14 18:38:35.454848: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
